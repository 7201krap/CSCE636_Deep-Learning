# %%
import numpy as np 
import matplotlib.pyplot as plt 
import time

# %matplotlib inline

import pylab as pl 
from IPython import display

# %%
m = 100 
w = np.array([[-6], [2], [1]])
X = np.hstack([np.ones([m, 1]), 4 * np.random.rand(m, 1), 4 * np.random.rand(m, 1)])

w = np.asmatrix(w)
X = np.asmatrix(X)

y = 1 / (1 + np.exp(-X*w)) > 0.5   # sigmoid function 

C0 = np.where(y == True)[0]
C1 = np.where(y == False)[0]

y = np.empty([m,1])
y[C1] = 1
y[C0] = -1
y = np.asmatrix(y)

# %%
plt.figure(figsize=(10, 6))
plt.plot(X[C0, 1], X[C0, 2], 'bo', label='C0')
plt.plot(X[C1, 1], X[C1, 2], 'ro', label='C1')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.legend()
plt.xlim([-1, 5])
plt.ylim([-1, 5])
plt.show()

# %%
# define sigmoid function 
# h == sigmoid function 

def h(x, w):
    return 1 / (1 + np.exp(-x*w))

# %%
w = np.zeros([3, 1])
w = np.asmatrix(w)

# %%
print(X.shape)
print(y.shape)
print(w.shape)
# Out:
# (100, 3)
# (100, 1)
# (3, 1)

# %%
lr = 1e-4

for k in range(10000):
    for i in range(100):
        
        # cross-entropy gradient 
        grad = y[i, 0] * X[i, :].T * (1 / (1 + np.exp(y[i, 0]*w.T*X[i, :].T))) 
        w = w + lr * grad
        
        if k % 100 == 0:
            plt.figure(figsize=(10, 6))
            
            # plotting
            # mark current data point with purple
            pl.scatter(X[i, 1], X[i, 2], alpha=0.5, c='purple', s=300)

            # show all points
            plt.plot(X[C0, 1], X[C0, 2], 'bo', label='C0')
            plt.plot(X[C1, 1], X[C1, 2], 'ro', label='C1')

            # decision boundary
            xp = np.linspace(0, 4, 100).reshape(-1, 1)
            yp = -w[1, 0] / w[2, 0] * xp - w[0, 0] / w[2, 0]
            pl.plot(xp, yp, 'g', label='Decision boundary with Logistic Regression')

            pl.xlabel('$x_1$')
            pl.ylabel('$x_2$')
            pl.legend(loc=2)
            pl.xlim([-1, 5])
            pl.ylim([-1, 5])
            pl.title(f'{i}-th data point in iteration(epoch) {k}: Logistic Regression with Gradient Descent')

            display.clear_output(wait=True)
            display.display(pl.gcf())
            time.sleep(0.01) 

            pl.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#      31 pl.title(f'{i}-th data point in iteration(epoch) {k}: Logistic Regression with Gradient Descent')
#      33 display.clear_output(wait=True)
# ---> 34 display.display(pl.gcf())
#      35 time.sleep(0.01)
#      37 pl.clf()
#
# File ~\anaconda3\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~\anaconda3\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~\anaconda3\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1172, in Axis.draw(self, renderer, *args, **kwargs)
#    1165 # scale up the axis label box to also find the neighbors, not
#    1166 # just the tick labels that actually overlap note we need a
#    1167 # *copy* of the axis label box because we don't want to scale
#    1168 # the actual bbox
#    1170 self._update_label_position(renderer)
# -> 1172 self.label.draw(renderer)
#    1174 self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#    1175 self.offsetText.set_text(self.major.formatter.get_offset())
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\text.py:685, in Text.draw(self, renderer)
#     682 renderer.open_group('text', self.get_gid())
#     684 with self._cm_set(text=self._get_wrapped_text()):
# --> 685     bbox, info, descent = self._get_layout(renderer)
#     686     trans = self.get_transform()
#     688     # don't use self.get_position here, which refers to text
#     689     # position in Text:
#
# File ~\anaconda3\lib\site-packages\matplotlib\text.py:317, in Text._get_layout(self, renderer)
#     315 clean_line, ismath = self._preprocess_math(line)
#     316 if clean_line:
# --> 317     w, h, d = renderer.get_text_width_height_descent(
#     318         clean_line, self._fontproperties, ismath=ismath)
#     319 else:
#     320     w = h = d = 0
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:265, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     261     return w, h, d
#     263 if ismath:
#     264     ox, oy, width, height, descent, fonts, used_characters = \
# --> 265         self.mathtext_parser.parse(s, self.dpi, prop)
#     266     return width, height, descent
#     268 flags = get_hinting_flag()
#
# File ~\anaconda3\lib\site-packages\matplotlib\mathtext.py:435, in MathTextParser.parse(self, s, dpi, prop, _force_standard_ps_fonts)
#     420     _api.warn_deprecated(
#     421         "3.4",
#     422         removal="3.5",
#    (...)
#     429         )
#     430     )
#     432 # lru_cache can't decorate parse() directly because the ps.useafm and
#     433 # mathtext.fontset rcParams also affect the parse (e.g. by affecting
#     434 # the glyph metrics).
# --> 435 return self._parse_cached(s, dpi, prop, _force_standard_ps_fonts)
#
# File ~\anaconda3\lib\site-packages\matplotlib\mathtext.py:456, in MathTextParser._parse_cached(self, s, dpi, prop, force_standard_ps_fonts)
#     453 if self._parser is None:
#     454     self.__class__._parser = _mathtext.Parser()
# --> 456 box = self._parser.parse(s, font_output, fontsize, dpi)
#     457 font_output.set_canvas_size(box.width, box.height, box.depth)
#     458 return font_output.get_results(box)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:2237, in Parser.parse(self, s, fonts_object, fontsize, dpi)
#    2235 self._em_width_cache = {}
#    2236 try:
# -> 2237     result = self._expression.parseString(s)
#    2238 except ParseBaseException as err:
#    2239     raise ValueError("\n".join(["",
#    2240                                 err.line,
#    2241                                 " " * (err.column - 1) + "^",
#    2242                                 str(err)])) from err
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:1097, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1095     instring = instring.expandtabs()
#    1096 try:
# -> 1097     loc, tokens = self._parse(instring, 0)
#    1098     if parseAll:
#    1099         loc = self.preParse(instring, loc)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:5098, in Forward.parseImpl(self, instring, loc, doActions)
#    5093     warnings.warn(
#    5094         "Forward expression was never assigned a value, will not parse any input",
#    5095         stacklevel=stacklevel,
#    5096     )
#    5097 if not ParserElement._left_recursion_enabled:
# -> 5098     return super().parseImpl(instring, loc, doActions)
#    5099 # ## Bounded Recursion algorithm ##
#    5100 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5101 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5116 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5117 # recursion level is acceptable.
#    5118 with ParserElement.recursion_lock:
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4267, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4265 def parseImpl(self, instring, loc, doActions=True):
#    4266     if self.expr is not None:
# -> 4267         return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4268     else:
#    4269         raise ParseException("", loc, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:3802, in And.parseImpl(self, instring, loc, doActions)
#    3798         raise ParseSyntaxException(
#    3799             instring, len(instring), self.errmsg, self
#    3800         )
#    3801 else:
# -> 3802     loc, exprtokens = e._parse(instring, loc, doActions)
#    3803 if exprtokens or exprtokens.haskeys():
#    3804     resultlist += exprtokens
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4774, in ZeroOrMore.parseImpl(self, instring, loc, doActions)
#    4772 def parseImpl(self, instring, loc, doActions=True):
#    4773     try:
# -> 4774         return super().parseImpl(instring, loc, doActions)
#    4775     except (ParseException, IndexError):
#    4776         return loc, ParseResults([], name=self.resultsName)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4682, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4680 if check_ender:
#    4681     try_not_ender(instring, loc)
# -> 4682 loc, tokens = self_expr_parse(instring, loc, doActions)
#    4683 try:
#    4684     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:3780, in And.parseImpl(self, instring, loc, doActions)
#    3777 def parseImpl(self, instring, loc, doActions=True):
#    3778     # pass False as callPreParse arg to _parse for first element, since we already
#    3779     # pre-parsed the string as part of our And pre-parsing
# -> 3780     loc, resultlist = self.exprs[0]._parse(
#    3781         instring, loc, doActions, callPreParse=False
#    3782     )
#    3783     errorStop = False
#    3784     for e in self.exprs[1:]:
#    3785         # if isinstance(e, And._ErrorStop):
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:824, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     822 for fn in self.parseAction:
#     823     try:
# --> 824         tokens = fn(instring, tokensStart, retTokens)
#     825     except IndexError as parse_action_exc:
#     826         exc = ParseException("exception raised in parse action")
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:282, in _trim_arity.<locals>.wrapper(*args)
#     280 while 1:
#     281     try:
# --> 282         ret = func(*args[limit:])
#     283         found_arity = True
#     284         return ret
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:2300, in Parser.math_string(self, s, loc, toks)
#    2299 def math_string(self, s, loc, toks):
# -> 2300     return self._math_expression.parseString(toks[0][1:-1])
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:1097, in ParserElement.parse_string(self, instring, parse_all, parseAll)
#    1095     instring = instring.expandtabs()
#    1096 try:
# -> 1097     loc, tokens = self._parse(instring, 0)
#    1098     if parseAll:
#    1099         loc = self.preParse(instring, loc)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:5098, in Forward.parseImpl(self, instring, loc, doActions)
#    5093     warnings.warn(
#    5094         "Forward expression was never assigned a value, will not parse any input",
#    5095         stacklevel=stacklevel,
#    5096     )
#    5097 if not ParserElement._left_recursion_enabled:
# -> 5098     return super().parseImpl(instring, loc, doActions)
#    5099 # ## Bounded Recursion algorithm ##
#    5100 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5101 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5116 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5117 # recursion level is acceptable.
#    5118 with ParserElement.recursion_lock:
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4267, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4265 def parseImpl(self, instring, loc, doActions=True):
#    4266     if self.expr is not None:
# -> 4267         return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4268     else:
#    4269         raise ParseException("", loc, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4682, in _MultipleMatch.parseImpl(self, instring, loc, doActions)
#    4680 if check_ender:
#    4681     try_not_ender(instring, loc)
# -> 4682 loc, tokens = self_expr_parse(instring, loc, doActions)
#    4683 try:
#    4684     hasIgnoreExprs = not not self.ignoreExprs
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:5098, in Forward.parseImpl(self, instring, loc, doActions)
#    5093     warnings.warn(
#    5094         "Forward expression was never assigned a value, will not parse any input",
#    5095         stacklevel=stacklevel,
#    5096     )
#    5097 if not ParserElement._left_recursion_enabled:
# -> 5098     return super().parseImpl(instring, loc, doActions)
#    5099 # ## Bounded Recursion algorithm ##
#    5100 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5101 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5116 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5117 # recursion level is acceptable.
#    5118 with ParserElement.recursion_lock:
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4267, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4265 def parseImpl(self, instring, loc, doActions=True):
#    4266     if self.expr is not None:
# -> 4267         return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4268     else:
#    4269         raise ParseException("", loc, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4016, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4014 for e in self.exprs:
#    4015     try:
# -> 4016         return e._parse(
#    4017             instring,
#    4018             loc,
#    4019             doActions,
#    4020         )
#    4021     except ParseFatalException as pfe:
#    4022         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 887 (1 times), ParserElement._parseNoCache at line 787 (1 times)]
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:5098, in Forward.parseImpl(self, instring, loc, doActions)
#    5093     warnings.warn(
#    5094         "Forward expression was never assigned a value, will not parse any input",
#    5095         stacklevel=stacklevel,
#    5096     )
#    5097 if not ParserElement._left_recursion_enabled:
# -> 5098     return super().parseImpl(instring, loc, doActions)
#    5099 # ## Bounded Recursion algorithm ##
#    5100 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5101 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5116 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5117 # recursion level is acceptable.
#    5118 with ParserElement.recursion_lock:
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4267, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4265 def parseImpl(self, instring, loc, doActions=True):
#    4266     if self.expr is not None:
# -> 4267         return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4268     else:
#    4269         raise ParseException("", loc, self.errmsg, self)
#
#     [... skipping similar frames: ParserElement._parseCache at line 887 (1 times), ParserElement._parseNoCache at line 787 (1 times)]
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4016, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4014 for e in self.exprs:
#    4015     try:
# -> 4016         return e._parse(
#    4017             instring,
#    4018             loc,
#    4019             doActions,
#    4020         )
#    4021     except ParseFatalException as pfe:
#    4022         pfe.__traceback__ = None
#
#     [... skipping similar frames: ParserElement._parseCache at line 887 (1 times), ParserElement._parseNoCache at line 787 (1 times)]
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:5098, in Forward.parseImpl(self, instring, loc, doActions)
#    5093     warnings.warn(
#    5094         "Forward expression was never assigned a value, will not parse any input",
#    5095         stacklevel=stacklevel,
#    5096     )
#    5097 if not ParserElement._left_recursion_enabled:
# -> 5098     return super().parseImpl(instring, loc, doActions)
#    5099 # ## Bounded Recursion algorithm ##
#    5100 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5101 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5116 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5117 # recursion level is acceptable.
#    5118 with ParserElement.recursion_lock:
#
#     [... skipping similar frames: ParserElement._parseCache at line 887 (1 times), ParserElement._parseNoCache at line 787 (1 times), ParseElementEnhance.parseImpl at line 4267 (1 times)]
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4267, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4265 def parseImpl(self, instring, loc, doActions=True):
#    4266     if self.expr is not None:
# -> 4267         return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4268     else:
#    4269         raise ParseException("", loc, self.errmsg, self)
#
#     [... skipping similar frames: ParserElement._parseCache at line 887 (1 times), ParserElement._parseNoCache at line 787 (1 times)]
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4016, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4014 for e in self.exprs:
#    4015     try:
# -> 4016         return e._parse(
#    4017             instring,
#    4018             loc,
#    4019             doActions,
#    4020         )
#    4021     except ParseFatalException as pfe:
#    4022         pfe.__traceback__ = None
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:3780, in And.parseImpl(self, instring, loc, doActions)
#    3777 def parseImpl(self, instring, loc, doActions=True):
#    3778     # pass False as callPreParse arg to _parse for first element, since we already
#    3779     # pre-parsed the string as part of our And pre-parsing
# -> 3780     loc, resultlist = self.exprs[0]._parse(
#    3781         instring, loc, doActions, callPreParse=False
#    3782     )
#    3783     errorStop = False
#    3784     for e in self.exprs[1:]:
#    3785         # if isinstance(e, And._ErrorStop):
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4842, in Opt.parseImpl(self, instring, loc, doActions)
#    4840 self_expr = self.expr
#    4841 try:
# -> 4842     loc, tokens = self_expr._parse(instring, loc, doActions, callPreParse=False)
#    4843 except (ParseException, IndexError):
#    4844     default_value = self.defaultValue
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:5098, in Forward.parseImpl(self, instring, loc, doActions)
#    5093     warnings.warn(
#    5094         "Forward expression was never assigned a value, will not parse any input",
#    5095         stacklevel=stacklevel,
#    5096     )
#    5097 if not ParserElement._left_recursion_enabled:
# -> 5098     return super().parseImpl(instring, loc, doActions)
#    5099 # ## Bounded Recursion algorithm ##
#    5100 # Recursion only needs to be processed at ``Forward`` elements, since they are
#    5101 # the only ones that can actually refer to themselves. The general idea is
#    (...)
#    5116 # we expand using `doActions=False` and only run `doActions=True` if the next
#    5117 # recursion level is acceptable.
#    5118 with ParserElement.recursion_lock:
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4267, in ParseElementEnhance.parseImpl(self, instring, loc, doActions)
#    4265 def parseImpl(self, instring, loc, doActions=True):
#    4266     if self.expr is not None:
# -> 4267         return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4268     else:
#    4269         raise ParseException("", loc, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:787, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     785 if self.mayIndexError or preloc >= len_instring:
#     786     try:
# --> 787         loc, tokens = self.parseImpl(instring, preloc, doActions)
#     788     except IndexError:
#     789         raise ParseException(instring, len_instring, self.errmsg, self)
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:4016, in MatchFirst.parseImpl(self, instring, loc, doActions)
#    4014 for e in self.exprs:
#    4015     try:
# -> 4016         return e._parse(
#    4017             instring,
#    4018             loc,
#    4019             doActions,
#    4020         )
#    4021     except ParseFatalException as pfe:
#    4022         pfe.__traceback__ = None
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:887, in ParserElement._parseCache(self, instring, loc, doActions, callPreParse)
#     885 ParserElement.packrat_cache_stats[MISS] += 1
#     886 try:
# --> 887     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#     888 except ParseBaseException as pe:
#     889     # cache a copy of the exception, without the traceback
#     890     cache.set(lookup, pe.__class__(*pe.args))
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:824, in ParserElement._parseNoCache(self, instring, loc, doActions, callPreParse)
#     822 for fn in self.parseAction:
#     823     try:
# --> 824         tokens = fn(instring, tokensStart, retTokens)
#     825     except IndexError as parse_action_exc:
#     826         exc = ParseException("exception raised in parse action")
#
# File ~\anaconda3\lib\site-packages\pyparsing\core.py:282, in _trim_arity.<locals>.wrapper(*args)
#     280 while 1:
#     281     try:
# --> 282         ret = func(*args[limit:])
#     283         found_arity = True
#     284         return ret
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:2356, in Parser.symbol(self, s, loc, toks)
#    2354 c, = toks
#    2355 try:
# -> 2356     char = Char(c, self.get_state())
#    2357 except ValueError as err:
#    2358     raise ParseFatalException(s, loc,
#    2359                               "Unknown symbol: %s" % c) from err
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:1156, in Char.__init__(self, c, state, math)
#    1153 self.math = math
#    1154 # The real width, height and depth will be set during the
#    1155 # pack phase, after we know the real fontsize
# -> 1156 self._update_metrics()
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:1162, in Char._update_metrics(self)
#    1161 def _update_metrics(self):
# -> 1162     metrics = self._metrics = self.font_output.get_metrics(
#    1163         self.font, self.font_class, self.c, self.fontsize, self.dpi,
#    1164         self.math)
#    1165     if self.c == ' ':
#    1166         self.width = metrics.advance
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:150, in Fonts.get_metrics(self, font, font_class, sym, fontsize, dpi, math)
#     112 def get_metrics(self, font, font_class, sym, fontsize, dpi, math=True):
#     113     r"""
#     114     Parameters
#     115     ----------
#    (...)
#     148           (currently used for kerning sub/superscripts).
#     149     """
# --> 150     info = self._get_info(font, font_class, sym, fontsize, dpi, math)
#     151     return info.metrics
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:268, in TruetypeFonts._get_info(self, fontname, font_class, sym, fontsize, dpi, math)
#     264 if bunch is not None:
#     265     return bunch
#     267 font, num, symbol_name, fontsize, slanted = \
# --> 268     self._get_glyph(fontname, font_class, sym, fontsize, math)
#     270 font.set_size(fontsize, dpi)
#     271 glyph = font.load_char(
#     272     num,
#     273     flags=self.mathtext_backend.get_hinting_type())
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:602, in DejaVuFonts._get_glyph(self, fontname, font_class, sym, fontsize, math)
#     599 else:
#     600     # check whether the glyph is available in the display font
#     601     uniindex = get_unicode_index(sym)
# --> 602     font = self._get_font('ex')
#     603     if font is not None:
#     604         glyphindex = font.get_char_index(uniindex)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_mathtext.py:249, in TruetypeFonts._get_font(self, font)
#     247     basename = font
#     248 cached_font = self._fonts.get(basename)
# --> 249 if cached_font is None and os.path.exists(basename):
#     250     cached_font = get_font(basename)
#     251     self._fonts[basename] = cached_font
#
# File ~\anaconda3\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:
